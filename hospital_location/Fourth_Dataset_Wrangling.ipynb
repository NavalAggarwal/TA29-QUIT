# %%
# import all packages required.
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
df4 = pd.read_csv("./Open Data/public_hospital_list.csv")

# %%
df4.head()
# Out:
#   State              Hospital name Establishment ID Medicare Provider No.  \
# 0   ACT  Calvary Health Care Bruce        810000083              3531230T
# 1   ACT          Canberra Hospital        810000082              0090030B
# 2   ACT         QEII Family Centre        810000084              0090020F
# 3   NSW                   Armidale        1180J2010              0010570T
# 4   NSW                     Auburn        1174D2010              0010020A
#
#    Local Hospital Network identifier        Local Hospital Network  \
# 0                                801  Australian Capital Territory
# 1                                801  Australian Capital Territory
# 2                                801  Australian Capital Territory
# 3                                109            Hunter New England
# 4                                104                Western Sydney
#
#                                       Address Line 1  \
# 0  1 Hayden                                      ...
# ...

# %%
df4 = df4.loc[df4["State"]=="VIC"]

# %%
df4.head()
# Out:
#     State                           Hospital name Establishment ID  \
# 453   VIC   Albury Wodonga Health [Albury Campus]        210N01650
# 454   VIC  Albury Wodonga Health [Wodonga Campus]        210401660
# 455   VIC             Alexandra District Hospital        210403010
# 456   VIC                  Alpine Health [Bright]        210401882
# 457   VIC            Alpine Health [Mount Beauty]        210401883
#
#     Medicare Provider No.  Local Hospital Network identifier  \
# 453              0010560W                                249
# 454              0031390A                                249
# 455              0030010T                                233
# 456              0031740W                                245
# 457              0031190J                                245
#
#           Local Hospital Network  \
# 453        Albury Wodonga Health
# 454        Albury Wodonga Health
# 455  Alexandra District Hospital
# 456          Alpine Health (Vic)
# ...

# %%
# write the data as a wrangled file.
df4.to_csv("vic_hospital_loc.csv", index = False)
